# %%
import pandas as pd
import openpyxl

df = pd.read_csv(
    "retail_sales.csv",
    dtype={
        "Category":"category",
        "Region":"category"
    }
)
df.info()

# %%
df.to_excel("subset_sales.xlsx",sheet_name="sale")
df.to_json(
   "subset_sales.json",
   orient="records",
   date_format="iso"

)

print("File Exported")
df.info()
# Out:
# File Exported
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_ID     15 non-null     str
#  1   Product         15 non-null     str
#  2   Category        15 non-null     category
#  3   Region          15 non-null     category
#  4   Quantity        15 non-null     int64
#  5   Price           15 non-null     int64
#  6   Payment_Method  15 non-null     str
# dtypes: category(2), int64(2), str(3)
# memory usage: 1.1 KB
